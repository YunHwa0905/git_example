# %%
a = 3
b = 5
a+b
# Out:
# 8

# %%
import pandas as pd

# %%
try:
    inDf = pd.read_csv("./dataset/sample.txt")
    inDf
except Exception as e:
    print(e)
# Out:
#   reginid   pty
# 0     a01   100

# %%
# load .env 파일 가져오기
